# %%
image_folder = "./TransGranCanaria2020/Images/"
image_name   = "00635transgrancanaria2020-18682.JPG"
face_folder  = "./ImageFaces/"
debug        = True

def preWorkArguments():
    args = {
        "transGranCanariaFolder": "/home/carlos/Escritorio/TFT/TransGranCanaria2020/",
        "destinationPath":        "/home/carlos/Escritorio/TFT/TransGranCanaria2020/Images/",
        "originalDataCsvName":    "108_transgrancanaria2020.csv",
        "dataCsvName":            "data.csv",
        "extendedDataCsvName":    "data2.csv",
        "sortedDataCsvName":      "dataSorted.csv",
        "resultData":             ["GPSInfo","Model","DateTime","Artist"],
        "mediaPath":              "/media/carlos/SEGURO/CARLITOS/108_transgrancanaria2020/",
        "dorsalCsvName":          "dorsales.csv",
        "RPDict": {'RP0':  {'GPSInfo': None, 'Model': None, 'Empty':True, 'count':0, 'Artist':None},
                   'RP1':  {'GPSInfo': None, 'Model': None, 'Empty':True, 'count':0, 'Artist':None},
                   'RP2':  {'GPSInfo': None, 'Model': None, 'Empty':True, 'count':0, 'Artist':None},
                   'RP3':  {'GPSInfo': None, 'Model': None, 'Empty':True, 'count':0, 'Artist':None},
                   'RP4':  {'GPSInfo': None, 'Model': None, 'Empty':True, 'count':0, 'Artist':None},
                   'RP5':  {'GPSInfo': None, 'Model': None, 'Empty':True, 'count':0, 'Artist':None},
                   'RP6':  {'GPSInfo': None, 'Model': None, 'Empty':True, 'count':0, 'Artist':None},
                   'RP7':  {'GPSInfo': None, 'Model': None, 'Empty':True, 'count':0, 'Artist':None},
                   'RP8':  {'GPSInfo': None, 'Model': None, 'Empty':True, 'count':0, 'Artist':None},
                   'RP9':  {'GPSInfo': None, 'Model': None, 'Empty':True, 'count':0, 'Artist':None},
                   'RP10': {'GPSInfo': None, 'Model': None, 'Empty':True, 'count':0, 'Artist':None},
                   'RP11': {'GPSInfo': None, 'Model': None, 'Empty':True, 'count':0, 'Artist':None},
                   'RP12': {'GPSInfo': None, 'Model': None, 'Empty':True, 'count':0, 'Artist':None},
                   'RP13': {'GPSInfo': None, 'Model': None, 'Empty':True, 'count':0, 'Artist':None},
                   'RP14': {'GPSInfo': None, 'Model': None, 'Empty':True, 'count':0, 'Artist':None},
                   'RP15': {'GPSInfo': None, 'Model': None, 'Empty':True, 'count':0, 'Artist':None},
                   'RP16': {'GPSInfo': None, 'Model': None, 'Empty':True, 'count':0, 'Artist':None}},
        "debug":             debug
    }
    return args

def yoloArguments():
    args = {
        "cocoNames":            "./Data/coco.names",
        "yoloWeights":          "./Data/yolov3.weights",
        "yoloCfg":              "./Data/yolov3.cfg",
        "image_path":           image_folder+image_name,
        "debug":                debug
    }
    return args

def fdArguments(coords=None):
    args = {
        "coords":               coords,
        "face_model":           "img2pose",#"retinaface",
        "landmark_model":       "mobilefacenet",
        "au_model":             "svm",
        "emotion_model":        "resmasknet",
        "facepose_model":       "img2pose",
        "pose_model":           "img2pose",
        "image_name":           image_name,
        "image_path":           image_folder+image_name,
        "face_folder":          face_folder,
        "emotions":             {'count': 0, 'anger': 0, 'disgust': 0, 'fear': 0, 
                                 'happiness': 0, 'sadness': 0,'surprise': 0,'neutral': 0},
        "debug":                debug
    }
    return args

def imageCalificationArguments():
    args ={
        "header":                 ["Image", "dorsal", "xmin", "xmax", "ymin", "ymax"],
        "dataFolder":             "/home/carlos/Escritorio/TFT/TransGranCanaria2020/",
        "imageFolder":            "/home/carlos/Escritorio/TFT/TransGranCanaria2020/Images/",
        "sortedDataCsvName":      "dataSorted.csv",
        "boxesDataCsvName":       "boxesData.csv",
        "emotionsDataCsvName":    "dorsalEmotions.csv"
        
    }
    
    return args

def statisticsExtractionsArguments():
    args ={
        "dataFolder":             "/home/carlos/Escritorio/TFT/TransGranCanaria2020/",
        "imageFolder":            "/home/carlos/Escritorio/TFT/TransGranCanaria2020/Images/",
        "sortedDataCsvName":      "dataSorted.csv",
        "boxesDataCsvName":       "boxesData.csv",
        "emotionsDataCsvName":    "dorsalEmotions.csv",
        "RPNumberLocations":       {1:  "Salida",
                                   2:  "Montaña (7Km)",
                                   5:  "Montaña (80Km)",
                                   3:  "Montaña (85Km)",
                                   4:  "Montaña (90Km)",
                                   6:  "Montaña (100)",
                                   7:  "Roca (110)",
                                   8:  "Roca (110)",
                                   9:  "Llegada",
                                   11: "Llegada",
                                   13: "Llegada"}
    }
    
    return args
